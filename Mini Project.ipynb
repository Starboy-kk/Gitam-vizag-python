# %% [markdown]
# <h1 align= 'center'>Mini Project on IPL Data-set</h1></font>
# Probelm Statement
# - 1.Display the count of matches based on the year wise
# - 2.Description of the problem

# %%
import pandas as pd
filepath = 'Datafiles/Match.csv'
def readCsvdata(filepath):
    return pd.read_csv(filepath)
df= readCsvdata(filepath)
a=df['Season_Year'].tolist()
c=df.groupby('Season_Year')['Season_Year'].count()
final = {'Matches':c}
final = pd.DataFrame(final)
final
# Out:
#               Matches
# Season_Year
# 2008               58
# 2009               57
# 2010               60
# 2011               73
# 2012               74
# 2013               76
# 2014               60
# 2015               59
# 2016               60
# 2017               60

# %% [markdown]
# Probelm Statement
# 2. Plot a bar graph no. of matches won by each team in the year 2011
# Description of the problem

# %%
c=df[df['Season_Year']==2011]
d=c['match_winner'].value_counts()
pd.DataFrame(d)
print(d)
print()
teams=[]
teams=d.index.tolist()
import matplotlib.pyplot as plt 
plt.barh(teams,d, color='blue')
# Out:
# Chennai Super Kings            11
# Mumbai Indians                 10
# Royal Challengers Bangalore    10
# Kolkata Knight Riders           8
# Kings XI Punjab                 7
# Kochi Tuskers Kerala            6
# Deccan Chargers                 6
# Rajasthan Royals                6
# Delhi Daredevils                4
# Pune Warriors                   4
# Name: match_winner, dtype: int64
# <BarContainer object of 10 artists>

# %%
r=df[df['City_Name']== 'Hyderabad']
y=c['ManOfMach'].value_counts()
y
final = {'Man of the match ':y}
final = pd.DataFrame(final)
final
# Out:
#                   Man of the match
# CH Gayle                          6
# MEK Hussey                        3
# V Kohli                           2
# V Sehwag                          2
# Iqbal Abdulla                     2
# R Sharma                          2
# BB McCullum                       2
# M Vijay                           2
# SK Warne                          2
# MM Patel                          2
# SL Malinga                        2
# BJ Hodge                          2
# YK Pathan                         2
# PC Valthaty                       2
# A Mishra                          2
# DW Steyn                          1
# SE Marsh                          1
# MS Dhoni                          1
# S Dhawan                          1
# S Anirudha                        1
# SK Raina                          1
# I Sharma                          1
# KA Pollard                        1
# KD Karthik                        1
# BA Bhatt                          1
# ...
